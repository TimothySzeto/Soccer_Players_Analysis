# %%
import pandas as pd

df = pd.read_csv('../../data/v1/fbref/Big5 2024-2025 std.csv')
header_list = list(df.columns)
print(header_list)
print(df)
# Out:
# ['Rk', 'Player', 'Nation', 'Pos', 'Squad', 'Comp', 'Age', 'Born', 'MP', 'Starts', 'Min', '90s', 'Gls', 'Ast', 'G+A', 'G-PK', 'PK', 'PKatt', 'CrdY', 'CrdR', 'Gls p90', 'Ast p90', 'G+A p90', 'G-PK p90', 'G+A-PK p90', 'Matches', '-9999']
#         Rk             Player   Nation Pos        Squad                Comp  \
# 0        1         Max Aarons  eng ENG  DF  Bournemouth  eng Premier League
# 1        2         Max Aarons  eng ENG  DF     Valencia          es La Liga
# 2        3     Rodrigo Abajas   es ESP  DF     Valencia          es La Liga
# 3        4     James Abankwah   ie IRL  DF      Udinese          it Serie A
# 4        5  Keyliane Abdallah   fr FRA  FW    Marseille          fr Ligue 1
# ...    ...                ...      ...  ..          ...                 ...
# 2849  2850    Martin Ødegaard   no NOR  MF      Arsenal  eng Premier League
# 2850  2851       Leo Østigård   no NOR  DF   Hoffenheim       de Bundesliga
# ...

# %%
df.drop(columns=['Rk', 'Born', 'MP', 'Starts', 'Min', '90s', 'Matches', 'Gls p90', 'Ast p90', 'G+A p90', 'G-PK p90', 'G+A-PK p90'], inplace=True)
header_list = list(df.columns)
print(header_list)
df.head(20)
# Out:
# ['Player', 'Nation', 'Pos', 'Squad', 'Comp', 'Age', 'Gls', 'Ast', 'G+A', 'G-PK', 'PK', 'PKatt', 'CrdY', 'CrdR', '-9999']
#                 Player   Nation   Pos          Squad                Comp  \
# 0           Max Aarons  eng ENG    DF    Bournemouth  eng Premier League
# 1           Max Aarons  eng ENG    DF       Valencia          es La Liga
# 2       Rodrigo Abajas   es ESP    DF       Valencia          es La Liga
# 3       James Abankwah   ie IRL    DF        Udinese          it Serie A
# 4    Keyliane Abdallah   fr FRA    FW      Marseille          fr Ligue 1
# 5     Yunis Abdelhamid   ma MAR    DF  Saint-Étienne          fr Ligue 1
# 6        Himad Abdelli   dz ALG    MF         Angers          fr Ligue 1
# 7   Mohamed Abdelmonem   eg EGY    DF           Nice          fr Ligue 1
# 8             Ali Abdi   tn TUN    MF           Nice          fr Ligue 1
# 9      Saud Abdulhamid   sa KSA    MF           Roma          it Serie A
# ...

# %%
df_temp = pd.read_csv('../../data/v1/fbref/Big5 2024-2025 Playing Time.csv')
df_temp.drop(columns=['Rk', 'Player', 'Nation', 'Pos', 'Squad', 'Comp', 'Age', 'Born', 'Matches'], inplace=True)
df = pd.merge(df, df_temp, on='-9999', how='left')
print(df.shape)
df.info()
# Out:
# (3185, 32)
# <class 'pandas.DataFrame'>
# RangeIndex: 3185 entries, 0 to 3184
# Data columns (total 32 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Player    3185 non-null   str
#  1   Nation    3183 non-null   str
#  2   Pos       3185 non-null   str
#  3   Squad     3185 non-null   str
#  4   Comp      3185 non-null   str
#  5   Age       3184 non-null   float64
#  6   Gls       3185 non-null   int64
#  7   Ast       3185 non-null   int64
#  8   G+A       3185 non-null   int64
#  9   G-PK      3185 non-null   int64
#  10  PK        3185 non-null   int64
#  11  PKatt     3185 non-null   int64
#  12  CrdY      3185 non-null   int64
#  13  CrdR      3185 non-null   int64
#  14  -9999     3185 non-null   str
#  15  MP        3185 non-null   int64
#  16  Min       3146 non-null   float64
#  17  Mn/MP     3146 non-null   float64
#  18  Min%      3146 non-null   float64
#  19  90s       3146 non-null   float64
# ...
